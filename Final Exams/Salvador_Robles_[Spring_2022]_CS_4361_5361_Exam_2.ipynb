# %% [markdown]
# # [Spring 2022] CS 4361 / 5361 - Exam 2

# %% [markdown]
# ## **Before you start**
#
# Make a copy of this Colab by clicking on File > Save a Copy in Drive

# %%
student_name = "Salvador Robles Herrera"
student_id = "80683116"

# %% [markdown]
# Total number of points: 108 [---8 points of extra credit---]

# %% [markdown]
# ### [4 points] Problem 1
#
# Which of the following is the functional form of logistic regression (assume your dataset has only one attribute/feature):
#
# **Option 0:** $f(x) = x_0 + w_0*w_1$
#
# **Option 1:** $f(x) = w_0 + w_1*x $
#
# **Option 2:** $f(x) = \frac{1}{1-e^{w_0 + w_1*x}}$
#
# **Option 3:** $f(x) = \frac{1}{1-e^{-(w_0 + w_1*x)}}$
#
# **Option 4:** $f(x) = \frac{1}{1+e^{w_0 + w_1*x}}$
#
# **Option 5:** $f(x) = \frac{1}{1+e^{-(w_0 + w_1*x)}}$
#
# **Option 6:** Something else

# %%
def get_prob1_ans():
  # 5 because of the sign
  return 5  # If you think the answer to 
            # the problem is option n, return n

# %% [markdown]
# ### [4 points] Problem 2
#
# A machine learning model is a function of the \_\_\_\_\_
#
# | Option 0 	| Option 1 	| Option 2 	| Option 3 	| Option 4 	| Option 5 	|
# |-	|-	|-	|-	|-	|-	|
# | code | loss | data | labels | gradient descent algorithm | Something else |

# %%
def get_prob2_ans():

  return 2  # If you think the answer to 
            # the problem is option n, return n

# %% [markdown]
# ### [4 points] Problem 3
#
# The *loss* is a function (usually represented with the letter J) of the  \_\_\_\_\_
#
# | Option 0 	| Option 1 	| Option 2 	| Option 3 	| Option 4 	| Option 5 	|
# |-	|-	|-	|-	|-	|-	|
# | code | attributes / features | test data | weights / parameters | gradient descent algorithm | Something else |

# %%
def get_prob3_ans():

  return 3  # If you think the answer to 
            # the problem is option n, return n

# %% [markdown]
# ### [4 points] Problem 4
#
# The Stochastic Gradient Descent algorithm includes a sequence of steps. Which is the correct ordering?
#
# a.Compute the gradient of the loss
#
# b.Randomly select a mini-batch of (x, y) from the training data
#
# c.Initialize weights
#
# d.Update values of weights
#
# e.Using current values of weight, produce predictions y_pred
#
# | Option 0 	| Option 1 	| Option 2 	| Option 3 	| Option 4 	|
# |-	|-	|-	|-	|-	|
# | b, c, e, d, a	| b, a, c, d, e 	| c, b, e, a, d 	| c, a, b, d, e |  Something else 	|

# %%
def get_prob4_ans():
  # Leave it like that
  return 0  # If you think the answer to 
            # the problem is option n, return n

# %% [markdown]
# ### [4 points] Problem 5
#
# In Gradient Descent, a negative derivative (slope) of parameter w means that we should:
#
# | Option 0 	| Option 1 	| Option 2 	| Option 3 	| Option 4 	|
# |-	|-	|-	|-	|-	|
# | Decrease w	| Increase w 	| Do not change w | RUN |  Something else 	|

# %%
def get_prob5_ans():
  # The derivative would be like \ going from left to right, meaning w increases
  return 1  # If you think the answer to 
            # the problem is option n, return n

# %% [markdown]
# ### [4 points] Problem 6
#
# What training problem is depicted here?
#
# ![image.png](data:image/png;base64,...)
#
#
# | Option 0 	| Option 1 	| Option 2 	| Option 3 	| Option 4 |
# |-	|-	|-	|-	|- |
# |  Loss function is not convex	| Bad initialization of w	| Learning rate is too large 	| Loss function is not differentiable | Something else 	|

# %%
def get_prob6_ans():

  return 2  # If you think the answer to 
            # the problem is option n, return n

# %% [markdown]
# ### [4 points] Problem 7
# Which statement about the diagram below is FALSE?
#
# **Option 0:** Both model 1 and model 2 could be improved via gradient descent.
#
# **Option 1:** The MSE for model 1 is 1.0
#
# **Option 2:** The MSE for model 2 is less than the MSE for model 1.
#
# **Option 3:** Something else

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def get_prob7_ans():
  # MSE of model 1 (red): (1^2 + 1^2 + 1^2)/3 = 1
  # MSE of model 2 (blue): (0^2 + 1^2 + 2^2)/3 = 5/3 
  return 2  # If you think the answer to 
            # the problem is option n, return n

# %% [markdown]
# ### [4 points] Problem 8
#
# Which of the following is the ReLU function?
#
# **Option 0:** $h(z) = log(z) * log(-z)$
#
# **Option 1:** $h(z) = w_0+w_1*z $
#
# **Option 2:** $h(z) = \frac{1}{1+e^{-z}}$
#
# **Option 3:** $h(z) = max(0,z)$
#
# **Option 4:** $h(z) = ∑(z-z')^2$
#
# **Option 5:** Something else

# %%
def get_prob8_ans():

  return 3  # If you think the answer to 
            # the problem is option n, return n

# %% [markdown]
# ### [4 points] Problem 9
#
# Consider this neural network diagram. The activation function for the hidden layer nodes is ReLU and the activation function for the output node is sigmoid. What output is produced when x1=0.5 and x2=1?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# | Option 0 	| Option 1 	| Option 2 	| Option 3 	|
# |-	|-	|-	|- |
# |  ~0.99	| ~0.01| 0.5 	| -0.5 |

# %%
def get_prob9_ans():
  # Linear combination of the inputs
  # h1 = relu(-3*0.5 + 3*1 + 0)= relu(1.5) = 1.5
  # h2 = relu(3*0.5 - 3*1 + 0) = relu(-1.5) = 0
  # y = sigmoid(4*1.5 + 4*0 -6) = sigmoid(6-6) = sigmoid(0) = 0.5
  return 2  # If you think the answer to 
            # the problem is option n, return n

# %% [markdown]
# ### [4 points] Problem 10
#
# Suppose you want to use logistic regression to build a sneaker classifier (binary classification task). If the model receives a 28x28 grayscale as input, how many parameters (weights) do you expect the model to contain?
#
# | Option 0 	| Option 1 	| Option 2 	| Option 3 	| Option 4 	| Option 5 	|
# |-	|-	|-	|-	|-	|-	|
# |  28 | 2 | 785 | 1,570 | 28 | Something else |

# %%
def get_prob10_ans():
  # 28*28 +1
  return 2  # If you think the answer to 
            # the problem is option n, return n

# %% [markdown]
# ### [4 points] Problem 11
#
# To minimize a given loss function with gradient descent, it needs to be  \_\_\_\_\_
#
#
# **Option 0:** Differentiable
#
# **Option 1:** Complex
#
# **Option 2:** Convex
#
# **Option 3:** Simple
#
# **Option 4:** Non-convex

# %%
def get_prob11_ans():
  # so to get to a minima
  return 2  # If you think the answer to 
            # the problem is option n, return n

# %% [markdown]
# ### [4 points] Problem 12
#
# Which of the following statements is FALSE?
#
# **Option 0:** It makes more sense to use logistic regression, as opposed to linear regression, if you are trying to build a cat detector.
#
# **Option 1:** Linear models can represent a lot more problems when we add non-linearities through feature engineering
#
# **Option 2:** Both linear regression models and logistic regression models can be trained by gradient descent.
#
# **Option 3:** Gradient descent updates the model's weights until the loss becomes zero

# %%
def get_prob12_ans():

  return 1  # If you think the answer to 
            # the problem is option n, return n

# %% [markdown]
# ### [4 points] Problem 13
#
# Which of the following scaling methods is preferred if your input examples are images?
#
# **Option 0:** Linear
#
# **Option 1:** Clipping
#
# **Option 2:** Log Scaling
#
# **Option 3:** Z-score
#
# **Option 4:** None of the above

# %%
def get_prob13_ans():
  # To get pixel values from 0 to 1
  return 0  # If you think the answer to 
            # the problem is option n, return n

# %% [markdown]
# ### [4 points] Problem 14
#
# Categorical features can be represented as binary vectors where all values are 0, except for one of them. This is called:
#
#
# **Option 0:** Binary representation
#
# **Option 1:** Categorical encoding
#
# **Option 2:** One-hot encoding
#
# **Option 3:** Nominal encoding
#
# **Option 4:** Out of vocabulary representation

# %%
def get_prob14_ans():

  return 2  # If you think the answer to 
            # the problem is option n, return n

# %% [markdown]
# ### [4 points] Problem 15
#
# What is the output of the convolutional operation given the following image and filter?
#
# ![image.png](data:image/png;base64,...)

# %%
def get_prob15_ans():
  # 0.5 + 1
  return 1.5  # Return your answer

# %% [markdown]
# ### [4 points] Problem 16
#
# Using embeddings as opposed to one-hot vectors to represent words generally results in better performance because:
#
# **Option 0:** It takes a lot of memory to store words using one-hot vectors
#
# **Option 1:** In contrast to one-hot vectors, word embeddings capute word meanings
#
# **Option 2:** Embeddings are more sparse than one-hot vectors
#
# **Option 3:** Something else

# %%
def get_prob16_ans():
  return 1

# %% [markdown]
# ### Resources
#
# You are allowed to have these pages open while working on the following problems (they all have a search bar):
#
# https://scikit-learn.org/stable/
#
# https://www.tensorflow.org/api_docs
#
# https://numpy.org/doc/stable/

# %% [markdown]
# ### [11 points] Problem 17
#
# Using a subset of the MNIST dataset, do the following:
#
# Implement method problem_17_part1
# 1. Build a logistic regression classifier on the training dataset
# 2. With the trained model, predict the class of all examples in the test dataset
# 3. Return predictions
#
# Implement method problem_17_part2
# 1. Using the parameters real_digit_id, sim_digit_id, y_pred, and y_test, return the number of test images whose true class is real_digit_id, but were misclassified as sim_digit_id.
#
# For reproducibility purposes, build your classifier as follows (we'll use sklearn):
#
#     model = LogisticRegression(solver='lbfgs', max_iter=1000,random_state=0)
#     model.fit(x, y)
#
# Here's an example that shows how to get class predictions (actual class labels, not probabilities) using the trained model.
#
#     predictions = model.predict(x)

# %%
from sklearn.linear_model import LogisticRegression
import numpy as np
import tensorflow as tf

def get_mnist_subset():
  np.random.seed(0) # For reproducibility purposes
  (x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
  x_train = x_train.reshape((x_train.shape[0], -1)) / 255.0 # Flatten images
  x_test = x_test.reshape((x_test.shape[0], -1)) / 255.0  # Flatten images

  train_idx = np.random.permutation(np.arange(x_train.shape[0]))
  test_idx = np.random.permutation(np.arange(x_test.shape[0]))

  x_train, y_train = x_train[train_idx], y_train[train_idx]
  x_test, y_test = x_test[test_idx], y_test[test_idx]

  return x_train[:2000], y_train[:2000], x_test[:500], y_test[:500]
   
# Feel free to add helper methods, just don't change the signature
def problem_17_part1():
  x_train, y_train, x_test, y_test = get_mnist_subset()

  # Your code goes here - Build model and return y_pred (test set predictions)
  model = LogisticRegression(solver='lbfgs', max_iter=1000,random_state=0)
  model.fit(x_train, y_train)

  preds = model.predict(x_test)

  return preds # Feel free to remove/change this line


def problem_17_part2(real_digit_id, sim_digit_id, y_pred, y_test):
  
  # Your code goes here

  mask = y_test == real_digit_id

  preds_masked = y_pred[mask]

  missclassified = preds_masked[preds_masked == sim_digit_id]

  count = len(missclassified)
   
  return count  # Feel free to change/remove this line

# %%
import numpy as np
# Test cases

def test_p17():
  problem_points = 11.0
  num_tests = 8

  passed_tests = 0

  x_train, y_train, x_test, y_test = get_mnist_subset()

  try:
    y_pred = problem_17_part1()
    passed_tests += (problem_17_part2(2, 8, y_pred, y_test) == 3)
    passed_tests += (problem_17_part2(2, 0, y_pred, y_test) == 2)
    passed_tests += (problem_17_part2(2, 7, y_pred, y_test) == 1)
    passed_tests += (problem_17_part2(3, 9, y_pred, y_test) == 2)
    passed_tests += (problem_17_part2(7, 1, y_pred, y_test) == 0)
    passed_tests += (problem_17_part2(9, 7, y_pred, y_test) == 3)
    passed_tests += (problem_17_part2(1, 8, y_pred, y_test) == 0)
    passed_tests += (problem_17_part2(5, 0, y_pred, y_test) == 1)
  except Exception as e:
    print("Problem 17 - Exception thrown: ", e)

  
  # Need to pass at least 3 test cases to get partial credit
  passed_tests = 0 if passed_tests < 3 else passed_tests
  points = (passed_tests/num_tests) * problem_points

  print("Problem 17:", points, "/", problem_points)


test_p17()
# Out:
# Problem 17: 11.0 / 11.0

# %% [markdown]
# ### [11 points] Problem 18
#
# Using a subset of the MNIST dataset, do the following:
#
# Implement method problem_18_part1
# 1. Build a support vector machine classifier on the training dataset
# 2. With the trained model, predict the class of all examples in the test dataset
# 3. Return predictions
#
# Implement method problem_18_part2
# 1. Using the parameters real_digit_id, sim_digit_id, y_pred, and y_test, return the number of test images whose predicted class is sim_digit_id, but whose true class is real_digit_id.
#
# For reproducibility purposes, build your classifier as follows (we'll use sklearn):
#
#     model = SVC(random_state=0)
#     model.fit(x, y)
#
# Here's an example that shows how to get class predictions (actual class labels, not probabilities) using the trained model.
#
#     predictions = model.predict(x)

# %%
from sklearn.svm import SVC
import numpy as np
import tensorflow as tf

def get_mnist_subset():
  np.random.seed(0) # For reproducibility purposes
  (x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
  x_train = x_train.reshape((x_train.shape[0], -1)) / 255.0 # Flatten images
  x_test = x_test.reshape((x_test.shape[0], -1)) / 255.0  # Flatten images

  train_idx = np.random.permutation(np.arange(x_train.shape[0]))
  test_idx = np.random.permutation(np.arange(x_test.shape[0]))

  x_train, y_train = x_train[train_idx], y_train[train_idx]
  x_test, y_test = x_test[test_idx], y_test[test_idx]

  return x_train[:2000], y_train[:2000], x_test[:500], y_test[:500]
   
# Feel free to add helper methods, just don't change the signature
def problem_18_part1():
  x_train, y_train, x_test, y_test = get_mnist_subset()

  # Your code goes here - Build model and return y_pred (test set predictions)

  model = SVC(random_state=0)
  model.fit(x_train, y_train)

  y_preds = model.predict(x_test)

  return y_preds # Feel free to remove/change this line


def problem_18_part2(real_digit_id, sim_digit_id, y_pred, y_test):

  # Your code goes here

  mask = y_pred == sim_digit_id

  reals_masked = y_test[mask]

  missclassified = reals_masked[reals_masked == real_digit_id]

  count = len(missclassified)


  return count  # Feel free to change/remove this line

# %%
import numpy as np
# Test cases

def test_p18():
  problem_points = 11.0
  num_tests = 8

  passed_tests = 0

  try:
    x_train, y_train, x_test, y_test = get_mnist_subset()
    y_pred = problem_18_part1()
    passed_tests += (problem_18_part2(2, 8, y_pred, y_test) == 0)
    passed_tests += (problem_18_part2(2, 0, y_pred, y_test) == 2)
    passed_tests += (problem_18_part2(2, 7, y_pred, y_test) == 0)
    passed_tests += (problem_18_part2(4, 9, y_pred, y_test) == 1)
    passed_tests += (problem_18_part2(7, 2, y_pred, y_test) == 3)
    passed_tests += (problem_18_part2(5, 2, y_pred, y_test) == 2)
    passed_tests += (problem_18_part2(9, 8, y_pred, y_test) == 1)
    passed_tests += (problem_18_part2(5, 0, y_pred, y_test) == 1)
  except Exception as e:
    print("Problem 18 - Exception thrown: ", e)
    
  # Need to pass at least 3 test cases to get partial credit
  passed_tests = 0 if passed_tests < 3 else passed_tests
  points = (passed_tests/num_tests) * problem_points

  print("Problem 18:", points, "/", problem_points)


test_p18()
# Out:
# Problem 18: 11.0 / 11.0

# %% [markdown]
# ### [11 points] Problem 19
#
# Using a subset of the MNIST dataset, do the following:
#
# Implement method problem_19_part1
#
# 1. Using the training dataset, build a k-means model (k=20).
# 2. Use the built model to assign cluster ids to all examples in the test dataset
# 3. Return vector of cluster ids for test examples
#
# Implement method problem_19_part2
# 1. Using parameters digit_id, y_test, y_test_cluster_ids,   return the id of the cluster that contains the largest number of test examples whose true class is digit_id.
#
#
# For reproducibility purposes, build your classifier as follows (we'll use sklearn):
#
#     model = KMeans(n_clusters=k, random_state=0)
#     model.fit(x)
#
# Here's an example that shows how to get the cluster assignments for the training examples:
#
#     model.labels_
#
# Here's an example that shows how to get cluster assignments of another dataset:
#
#     model.predict(other_dataset)

# %%
from sklearn.cluster import KMeans
import numpy as np
import tensorflow as tf

def get_mnist_subset():
  np.random.seed(0) # For reproducibility purposes
  (x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
  x_train = x_train.reshape((x_train.shape[0], -1)) / 255.0 # Flatten images
  x_test = x_test.reshape((x_test.shape[0], -1)) / 255.0  # Flatten images

  train_idx = np.random.permutation(np.arange(x_train.shape[0]))
  test_idx = np.random.permutation(np.arange(x_test.shape[0]))

  x_train, y_train = x_train[train_idx], y_train[train_idx]
  x_test, y_test = x_test[test_idx], y_test[test_idx]

  return x_train[:2000], y_train[:2000], x_test[:500], y_test[:500]
   
# Feel free to add helper methods, just don't change the signature

def problem_19_part1():
  x_train, y_train, x_test, y_test = get_mnist_subset()

  # Your code goes here - Build model and return y_test_cluster_ids 

  model = KMeans(n_clusters=20, random_state=0)
  model.fit(x_train)

  model_preds = model.predict(x_test)

  return model_preds # Feel free to remove/change this line


def problem_19_part2(digit_id, y_test, y_test_cluster_ids):
  
  mask = y_test == digit_id

  preds_masked = y_test_cluster_ids[mask]
  
  return np.argmax(np.bincount(preds_masked))  # Feel free to change/remove this line

# %%
import numpy as np
# Test cases

def test_p19():
  problem_points = 11.0
  num_tests = 10

  passed_tests = 0

  try:
    x_train, y_train, x_test, y_test = get_mnist_subset()
    y_test_cluster_ids = problem_19_part1()

    s = [1, 18, 10, 14, 18, 12, 4, 3, 9, 7]
    for i in range(num_tests):
      passed_tests += (problem_19_part2(i, y_test, y_test_cluster_ids) == s.pop())
  except Exception as e:
      print("Problem 19 - Exception thrown: ", e)
  
  # Need to pass at least 3 test cases to get partial credit
  passed_tests = 0 if passed_tests < 3 else passed_tests
  points = (passed_tests/num_tests) * problem_points

  print("Problem 19:", points, "/", problem_points)


test_p19()
# Out:
# Problem 19: 11.0 / 11.0

# %% [markdown]
# ### [11 points] Problem 20
#
# Change the architecture of the convolutional neural network defined in build_model (add/remove layers, change the number of units/filters, etc.) so it achieves an accuracy of 0.4 or better on the validation dataset. We will use a subset of CIFAR-10. You are not allowed to change any code outside of the build_model method (you can't change the number of epochs, mini-batch size, etc.).

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from tensorflow import keras

# Change the model architecture defined in this method
def build_model(input_shape, num_classes=10):  
  model = keras.Sequential()

  model.add(keras.layers.Conv2D(filters=16, kernel_size=(4, 4), padding='same',
                  input_shape=input_shape))
  
  model.add(keras.layers.Activation('relu'))
  model.add(keras.layers.MaxPooling2D(pool_size=(1, 1)))
  model.add(keras.layers.Activation('relu'))
  model.add(keras.layers.Flatten())
  model.add(keras.layers.Activation('relu'))
  model.add(keras.layers.Dense(units=num_classes))
  model.add(keras.layers.Activation('softmax'))

  
  return model


# Do not change the code inside of this method
def get_cifar10_subset():
  np.random.seed(0) # For reproducibility purposes
  (x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
  x_train = x_train / 255.0 
  x_test = x_test / 255.0  

  train_idx = np.random.permutation(np.arange(x_train.shape[0]))
  test_idx = np.random.permutation(np.arange(x_test.shape[0]))

  x_train, y_train = x_train[train_idx], y_train[train_idx]
  x_test, y_test = x_test[test_idx], y_test[test_idx]

  return x_train[:2000], y_train[:2000], x_test[:500], y_test[:500]


# Do not change the code inside of this method
def train_model():
  x_train, y_train, x_test, y_test = get_cifar10_subset()

  tf.keras.backend.clear_session()
  np.random.seed(0)
  tf.random.set_seed(0)

  model = build_model(x_train[0].shape)
  
  loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False)
  optimizer = tf.keras.optimizers.Adam()
  
  model.compile(loss=loss,
              optimizer=optimizer,
              metrics=['accuracy'])
  
  h = model.fit(
    x = x_train,   
    y = y_train,  
    epochs=5,    
    batch_size=64, 
    validation_data=(x_test, y_test),
    verbose=1   
  )

  val_acc = h.history['val_accuracy'][-1]
  print("Final validation accuracy:", val_acc)
  return val_acc

# %%
import numpy as np
# Test cases

def test_p20():
  problem_points = 11.0
  num_tests = 1

  try:
    passed_tests = int(train_model() >= 0.4)
  except Exception as e:
    print("Problem 20 - Exception thrown: ", e)

  points = (passed_tests/num_tests) * problem_points

  print("Problem 20:", points, "/", problem_points)


test_p20()
# Out:
# Epoch 1/5
# 32/32 [==============================] - 2s 61ms/step - loss: 2.1697 - accuracy: 0.2085 - val_loss: 2.0107 - val_accuracy: 0.2320
# Epoch 2/5
# 32/32 [==============================] - 2s 54ms/step - loss: 1.7852 - accuracy: 0.3810 - val_loss: 1.8299 - val_accuracy: 0.3420
# Epoch 3/5
# 32/32 [==============================] - 2s 55ms/step - loss: 1.6000 - accuracy: 0.4570 - val_loss: 1.7502 - val_accuracy: 0.3640
# Epoch 4/5
# 32/32 [==============================] - 2s 53ms/step - loss: 1.4137 - accuracy: 0.5300 - val_loss: 1.7141 - val_accuracy: 0.4060
# Epoch 5/5
# 32/32 [==============================] - 2s 53ms/step - loss: 1.2467 - accuracy: 0.5920 - val_loss: 1.6689 - val_accuracy: 0.4100
# Final validation accuracy: 0.4099999964237213
# Problem 20: 11.0 / 11.0

# %% [markdown]
# ## How to Submit This Exam
#
# 1. File > Download .ipynb
# 2. Go to Blackboard, find the lab submission page, and upload the .ipynb file you just downloaded.
